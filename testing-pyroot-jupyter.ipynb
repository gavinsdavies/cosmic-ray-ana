# %%
import ROOT
# Out:
# Welcome to JupyROOT 6.28/04

# %%
import sys

# %%
h= ROOT.TH1F("gaussian","Example",100,-4,4)

# %%
h.FillRandom("gaus")

# %%
c = ROOT.TCanvas("myC","canvas",800,600)

# %%
h.Draw()

# %%
c.Draw()

# %%
func = ROOT.TF2("myfunc","sin(x)*sin(y)",-4,4,-4,4)

# %%
func.Draw()

# %%
c.Draw()

# %%
inFileName = "data/fardet_data_2_run16043_R20-11-25-cosfilt.c_r16043.0-r16043.45.cosmic_ntuple.root"

# %%
inFile = ROOT.TFile.Open(inFileName, "READ")

# %%
tree = inFile.Get("cosmicntuple/cosmicTree")

# %%
hTest = ROOT.TH1D("startx","hTest - data", 150, 50, 200)

# %%
for entryNum in range(0, tree.GetEntries()):
    tree.GetEntry(entryNum)
    if getattr(tree, "ntrack") == 0:
        continue
    startX = getattr(tree, "startPosX")[0]
    hTest.Fill(startX)

# %%
hTest.Draw()

# %%
c.Draw()

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
textFile = open("data/test.txt", "r")

# %%
lines = textFile.read().split('\n')

# %%
print(lines)
# Out:
# ['10 20 30 40 50', '5 6 9 10 12', '']

# %%
arr = np.loadtxt("data/test.txt", unpack=True)

# %%
print(arr)
# Out:
# [[10.  5.]
#  [20.  6.]
#  [30.  9.]
#  [40. 10.]
#  [50. 12.]]

# %%
print(arr[0])
# Out:
# [10.  5.]

# %%
x = arr[0, :]

# %%
print(x)
# Out:
# [10.  5.]

# %%
y = arr[1, :]

# %%
print(y)
# Out:
# [20.  6.]

# %%
x = arr[;, 0]
# Out:
#   Cell In[74], line 1
#     x = arr[;, 0]
#             ^
# SyntaxError: invalid syntax

# %%
x = arr[:, 0]

# %%
print(x)
# Out:
# [10. 20. 30. 40. 50.]

# %%
y = arr[:, 0]

# %%
print y
# Out:
#   Cell In[78], line 1
#     print y
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %%
print(y)
# Out:
# [10. 20. 30. 40. 50.]

# %%
y = arr[:, 1]

# %%
print(y)
# Out:
# [ 5.  6.  9. 10. 12.]

# %%
plt.bar(x, y)
# Out:
# <BarContainer object of 5 artists>

# %%
g = ROOT.TGraph(len(x), x , y)

# %%
g.Draw()

# %%
c.Update()

# %%
g.Draw("")

# %%
c.Draw()

# %%
g.SetMarkerStyle(ROOT.kFullCircle)

# %%
c.Draw()
